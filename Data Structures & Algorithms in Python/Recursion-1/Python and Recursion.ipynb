# %% [markdown]
# # Recursion Depth

# %%
def fact(n):
    if n==0:
        return 1
    return n*fact(n-1)

# %%
def fact1(n):
    if n==0:
        return 1
    smallOutput=fact(n-1)
    return n*smallOutput

# %%
n=int(input())
fact(n)
# Out:
# 100
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
n=int(input())
fact(n)
# Out:
# 5
# 120

# %%
n=int(input())
fact(n)
# Out:
# 369
# ...

# %%
n=int(input())
fact(n)
# Out:
# 900
# ...

# %%
n=int(input())
fact(n)
# Out:
# 2099
# ...

# %%
n=int(input())
fact(n)                 # recursion limit
# Out:
# 3000
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-12-a48bacb7ff43> in <module>
#       1 n=int(input())
# ----> 2 fact(n)
#
# <ipython-input-1-54eb7527399e> in fact(n)
#       2     if n==0:
#       3         return 1
# ----> 4     return n*fact(n-1)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-1-54eb7527399e> in fact(n)
#       2     if n==0:
#       3         return 1
# ----> 4     return n*fact(n-1)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
import sys
sys.setrecursionlimit(4000)

# %%
n=int(input())
fact(n)
# Out:
# 3000
# ...
