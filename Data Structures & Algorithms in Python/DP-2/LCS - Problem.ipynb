# %% [markdown]
# # LCS - Problem
# Send Feedback
# Given two strings, 'S' and 'T' with lengths 'M' and 'N', find the length of the 'Longest Common Subsequence'.
# For a string 'str'(per se) of length K, the subsequences are the strings containing characters in the same relative order as they are present in 'str,' but not necessarily contiguous. Subsequences contain all the strings of length varying from 0 to K.
# Example :
# Subsequences of string "abc" are:  ""(empty string), a, b, c, ab, bc, ac, abc.
# Input format :
# The first line of input contains the string 'S' of length 'M'.
#
# The second line of the input contains the string 'T' of length 'N'.
# Output format :
# Return the length of the Longest Common Subsequence.
# Constraints :
# 0 <= M <= 10 ^ 3
# 0 <= N <= 10 ^ 3
#
# Time Limit: 1 sec
# Sample Input 1 :
# adebc
# dcadb
# Sample Output 1 :
# 3
# Explanation of the Sample Output 1 :
# Both the strings contain a common subsequence 'adb', which is the longest common subsequence with length 3.
# Sample Input 2 :
# ab
# defg
# Sample Output 2 :
# 0
# Explanation of the Sample Output 2 :
# The only subsequence that is common to both the given strings is an empty string("") of length 0.

# %%
from sys import stdin

def lcs(s, t) :
    n = len(s)
    m=len(t)
    dp = [[0 for x in range(0,m)] for y in range(0,n)]
    
    for i in range(0,m):
        if s[0]==t[i]:
        	dp[0][i]=1
        if i>0:
            dp[0][i]=max(dp[0][i],dp[0][i-1])
    for i in range(0,n):
        if t[0]==s[i]:
            dp[i][0]=1
        if i > 0 :
            dp[i][0]=max(dp[i][0],dp[i-1][0])
    
    for i in range(1,n):
        for j in range(1,m):
            dp[i][j]=dp[i-1][j-1]
            if s[i] == t[j] :
                dp[i][j] += 1 
            dp[i][j]=max(dp[i][j],max(dp[i-1][j],dp[i][j-1]))
    return dp[n-1][m-1]






























    


#main
s = str(stdin.readline().rstrip())
t = str(stdin.readline().rstrip())

print(lcs(s, t))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-6e121d73d9ec> in <module>
#      61 t = str(stdin.readline().rstrip())
#      62
# ---> 63 print(lcs(s, t))
#
# <ipython-input-1-6e121d73d9ec> in lcs(s, t)
#      23                 dp[i][j] += 1
#      24             dp[i][j]=max(dp[i][j],max(dp[i-1][j],dp[i][j-1]))
# ---> 25     return dp[n-1][m-1]
#      26
#      27
#
# IndexError: list index out of range
